# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import time
import seaborn as sns

# %matplotlib inline
pd.set_option('display.max_columns', None)

# %%
# Read in csv data
cats = pd.read_csv('..//data/cats.csv')
barnyard = pd.read_csv('..//data/barnyard.csv')
dogs = pd.read_csv('..//data/dogs.csv')
horses = pd.read_csv('..//data/horses.csv')
rabbits = pd.read_csv('..//data/rabbits.csv')
scales = pd.read_csv('..//data/scales.csv')
smallandfurry = pd.read_csv('..//data/smallandfurry.csv')

# %%
print(cats.shape)
print(barnyard.shape)
print(dogs.shape)
print(horses.shape)
print(rabbits.shape)
print(scales.shape)
print(smallandfurry.shape)
# Out:
# (14240, 50)
# (27, 50)
# (19893, 50)
# (16, 62)
# (161, 62)
# (2, 49)
# (63, 51)

# %%
# Combine datasets into one dataframe
df = pd.concat([cats, barnyard, dogs, horses, rabbits, scales, smallandfurry])
df.reset_index(drop=True, inplace=True)
df.shape
# Out:
# (34402, 63)

# %% [markdown]
# ### Drop Duplicates

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (34010, 63)

# %%
df.head()
# Out:
#            id organization_id  \
# 0  70208019.0           TN801
# 1  70207823.0           TN597
# 2  70207450.0           TN369
# 3  70203376.0            TN90
# 4  70203375.0            TN90
#
#                                                  url type species    age  \
# 0  https://www.petfinder.com/cat/madame-kitty-702...  Cat     Cat  Young
# 1  https://www.petfinder.com/cat/truffles-7020782...  Cat     Cat   Baby
# 2  https://www.petfinder.com/cat/teetee-70207450/...  Cat     Cat   Baby
# 3  https://www.petfinder.com/cat/ac-25055-7020337...  Cat     Cat  Young
# 4  https://www.petfinder.com/cat/ac-25035-7020337...  Cat     Cat  Young
#
#    gender    size   coat                                     tags  \
# 0  Female  Medium  Short                                       []
# 1  Female   Small  Short  ['Friendly', 'Affectionate', 'Playful']
# 2    Male   Small  Short  ['Friendly', 'Affectionate', 'Playful']
# 3    Male  Medium    NaN                                       []
# 4  Female  Medium    NaN                                       []
#
#             name                                        description  \
# 0  Madame Kitty   Meet Madame Kitty, a 2 year old DSH cat. She i...
# 1       Truffles  Truffles is the new kid on the block.  This pr...
# 2         TeeTee  Meet TeeTee! He is an extremely adorable and s...
# 3       AC 25055                                                NaN
# 4       AC 25035                                                NaN
#
#   organization_animal_id                                             photos  \
# 0                    NaN  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 1                    NaN  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 2                1207-23  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 3              A2023C688                                                 []
# 4              A2023C687                                                 []
#
#   videos   status         status_changed_at              published_at  \
# 0     []  adopted  2024-01-22T13:31:21+0000  2023-12-31T23:19:08+0000
# 1     []  adopted  2024-01-18T00:05:29+0000  2023-12-31T22:40:37+0000
# 2     []  adopted  2024-01-06T00:56:45+0000  2023-12-31T21:45:47+0000
# 3     []  adopted  2023-12-31T10:03:59+0000  2023-12-31T10:03:58+0000
# 4     []  adopted  2023-12-31T10:03:57+0000  2023-12-31T10:03:56+0000
#
#    distance       breeds.primary breeds.secondary breeds.mixed breeds.unknown  \
# 0  120.4729  Domestic Short Hair              NaN        False          False
# 1   33.2060        Dilute Calico              NaN         True          False
# 2    7.6471  Domestic Short Hair              NaN        False          False
# 3  223.6873  Domestic Short Hair              NaN        False          False
# 4  223.6873  Domestic Short Hair              NaN        False          False
#
#                  colors.primary   colors.secondary colors.tertiary  \
# 0                        Calico                NaN             NaN
# 1                 Dilute Calico  Brown / Chocolate             NaN
# 2  Tabby (Gray / Blue / Silver)                NaN             NaN
# 3                           NaN                NaN             NaN
# 4                           NaN                NaN             NaN
#
#   attributes.spayed_neutered attributes.house_trained attributes.declawed  \
# 0                       True                     True                 0.0
# 1                       True                     True                 0.0
# 2                       True                     True                 0.0
# 3                      False                    False                 0.0
# 4                      False                    False                 0.0
#
#   attributes.special_needs attributes.shots_current environment.children  \
# 0                    False                     True                 True
# 1                    False                     True                 True
# 2                    False                     True                  NaN
# 3                    False                    False                  NaN
# 4                    False                    False                  NaN
#
#   environment.dogs environment.cats  \
# 0              NaN              NaN
# 1             True             True
# 2             True             True
# 3              NaN              NaN
# 4              NaN              NaN
#
#                          primary_photo_cropped.small  \
# 0  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 2  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3                                                NaN
# 4                                                NaN
#
#                         primary_photo_cropped.medium  \
# 0  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 2  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3                                                NaN
# 4                                                NaN
#
#                          primary_photo_cropped.large  \
# 0  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 2  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3                                                NaN
# 4                                                NaN
#
#                           primary_photo_cropped.full  \
# 0  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 2  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3                                                NaN
# 4                                                NaN
#
#                    contact.email   contact.phone  \
# 0  meowmeowkittyrescue@yahoo.com             NaN
# 1                            NaN  (931) 623-1266
# 2      fosterkittenstn@gmail.com             NaN
# 3                            NaN  (423) 639-4771
# 4                            NaN  (423) 639-4771
#
#                         contact.address.address1 contact.address.address2  \
# 0  2288 Gunbarrel Rd #172, Chattanooga, TN 37421                      NaN
# 1                                1163 Blake Road                      NaN
# 2                                P.O. Box 140898                      NaN
# 3                           400 N Rufe Taylor Rd                      NaN
# 4                           400 N Rufe Taylor Rd                      NaN
#
#   contact.address.city contact.address.state  contact.address.postcode  \
# 0         Chattanooga                     TN                   37421.0
# 1                Lyles                    TN                   37098.0
# 2            Nashville                    TN                   37214.0
# 3          Greeneville                    TN                   37745.0
# 4          Greeneville                    TN                   37745.0
#
#   contact.address.country      _links.self.href _links.type.href  \
# 0                      US  /v2/animals/70208019    /v2/types/cat
# 1                      US  /v2/animals/70207823    /v2/types/cat
# 2                      US  /v2/animals/70207450    /v2/types/cat
# 3                      US  /v2/animals/70203376    /v2/types/cat
# 4                      US  /v2/animals/70203375    /v2/types/cat
#
#   _links.organization.href  primary_photo_cropped  Unnamed: 50  Unnamed: 51  \
# 0  /v2/organizations/tn801                    NaN          NaN          NaN
# 1  /v2/organizations/tn597                    NaN          NaN          NaN
# 2  /v2/organizations/tn369                    NaN          NaN          NaN
# 3   /v2/organizations/tn90                    NaN          NaN          NaN
# 4   /v2/organizations/tn90                    NaN          NaN          NaN
#
#    Unnamed: 52  Unnamed: 53  Unnamed: 54  Unnamed: 55  Unnamed: 56  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 57  Unnamed: 58  Unnamed: 59  Unnamed: 60  Unnamed: 61  id.1
# 0          NaN          NaN          NaN          NaN          NaN   NaN
# 1          NaN          NaN          NaN          NaN          NaN   NaN
# 2          NaN          NaN          NaN          NaN          NaN   NaN
# 3          NaN          NaN          NaN          NaN          NaN   NaN
# 4          NaN          NaN          NaN          NaN          NaN   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34010 entries, 0 to 34401
# Data columns (total 63 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            34009 non-null  float64
#  1   organization_id               34009 non-null  object
#  2   url                           34009 non-null  object
#  3   type                          34009 non-null  object
#  4   species                       34009 non-null  object
#  5   age                           34009 non-null  object
#  6   gender                        34009 non-null  object
#  7   size                          34009 non-null  object
#  8   coat                          13600 non-null  object
#  9   tags                          34009 non-null  object
#  10  name                          34009 non-null  object
#  11  description                   19496 non-null  object
#  12  organization_animal_id        18989 non-null  object
#  13  photos                        34009 non-null  object
#  14  videos                        34009 non-null  object
#  15  status                        34009 non-null  object
#  16  status_changed_at             34009 non-null  object
#  17  published_at                  34009 non-null  object
#  18  distance                      34009 non-null  float64
#  19  breeds.primary                34009 non-null  object
#  20  breeds.secondary              8194 non-null   object
#  21  breeds.mixed                  34009 non-null  object
#  22  breeds.unknown                34009 non-null  object
#  23  colors.primary                15015 non-null  object
#  24  colors.secondary              5573 non-null   object
#  25  colors.tertiary               716 non-null    object
#  26  attributes.spayed_neutered    34009 non-null  object
#  27  attributes.house_trained      34009 non-null  object
#  28  attributes.declawed           14116 non-null  object
#  29  attributes.special_needs      34009 non-null  object
#  30  attributes.shots_current      34009 non-null  object
#  31  environment.children          11391 non-null  object
#  32  environment.dogs              12411 non-null  object
#  33  environment.cats              10485 non-null  object
#  34  primary_photo_cropped.small   31426 non-null  object
#  35  primary_photo_cropped.medium  31426 non-null  object
#  36  primary_photo_cropped.large   31426 non-null  object
#  37  primary_photo_cropped.full    31426 non-null  object
#  38  contact.email                 23603 non-null  object
#  39  contact.phone                 27046 non-null  object
#  40  contact.address.address1      23745 non-null  object
#  41  contact.address.address2      1504 non-null   object
#  42  contact.address.city          34009 non-null  object
#  43  contact.address.state         34009 non-null  object
#  44  contact.address.postcode      34009 non-null  float64
#  45  contact.address.country       34009 non-null  object
#  46  _links.self.href              34009 non-null  object
#  47  _links.type.href              34009 non-null  object
#  48  _links.organization.href      34009 non-null  object
#  49  primary_photo_cropped         0 non-null      float64
#  50  Unnamed: 50                   0 non-null      float64
#  51  Unnamed: 51                   0 non-null      float64
#  52  Unnamed: 52                   0 non-null      float64
#  53  Unnamed: 53                   0 non-null      float64
#  54  Unnamed: 54                   0 non-null      float64
#  55  Unnamed: 55                   0 non-null      float64
#  56  Unnamed: 56                   0 non-null      float64
#  57  Unnamed: 57                   0 non-null      float64
#  58  Unnamed: 58                   0 non-null      float64
#  59  Unnamed: 59                   0 non-null      float64
#  60  Unnamed: 60                   0 non-null      float64
#  61  Unnamed: 61                   0 non-null      float64
#  62  id.1                          0 non-null      float64
# dtypes: float64(17), object(46)
# memory usage: 16.6+ MB

# %% [markdown]
# ### Clean dtypes

# %%
#df.info()

# %%
# Change 'published_at' and 'status_changed'_at columns to datetime 
df['published_at'] = pd.to_datetime(df['published_at'])
df['status_changed_at'] = pd.to_datetime(df['status_changed_at'])

# %%
# Define function to switch dtypes to string
def string_clean(column):
    x = df[column].astype('string')
    return x

# %%
# Test
df['organization_id'] = string_clean('organization_id')

# %%
for column in df.columns:
    if df[column].dtype == 'object':
        df[column] = string_clean(column)

# %%
#df.info()

# %% [markdown]
# ### Drop unnecessary columns

# %%
#print(df.columns)

# %%
drop_list = [
    'organization_animal_id',
    'photos', 
    'videos',
    'distance',
    'primary_photo_cropped.small', 
    'primary_photo_cropped.medium',
    'primary_photo_cropped.large',
    'primary_photo_cropped.full',
    'contact.email', 
    'contact.phone', 
    'contact.address.address1',
    'contact.address.address2',
    'contact.address.country', 
    '_links.self.href', 
    '_links.type.href',
    '_links.organization.href',
    'primary_photo_cropped',
    'Unnamed: 50',
    'Unnamed: 51', 
    'Unnamed: 52', 
    'Unnamed: 53', 
    'Unnamed: 54',
    'Unnamed: 55', 
    'Unnamed: 56', 
    'Unnamed: 57', 
    'Unnamed: 58',
    'Unnamed: 59', 
    'Unnamed: 60', 
    'Unnamed: 61', 
    'id.1'
]

# %%
df.drop(columns=drop_list, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34010 entries, 0 to 34401
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          34009 non-null  float64
#  1   organization_id             34009 non-null  string
#  2   url                         34009 non-null  string
#  3   type                        34009 non-null  string
#  4   species                     34009 non-null  string
#  5   age                         34009 non-null  string
#  6   gender                      34009 non-null  string
#  7   size                        34009 non-null  string
#  8   coat                        13600 non-null  string
#  9   tags                        34009 non-null  string
#  10  name                        34009 non-null  string
#  11  description                 19496 non-null  string
#  12  status                      34009 non-null  string
#  13  status_changed_at           34009 non-null  datetime64[ns, UTC]
#  14  published_at                34009 non-null  datetime64[ns, UTC]
#  15  breeds.primary              34009 non-null  string
#  16  breeds.secondary            8194 non-null   string
#  17  breeds.mixed                34009 non-null  string
#  18  breeds.unknown              34009 non-null  string
#  19  colors.primary              15015 non-null  string
#  20  colors.secondary            5573 non-null   string
#  21  colors.tertiary             716 non-null    string
#  22  attributes.spayed_neutered  34009 non-null  string
#  23  attributes.house_trained    34009 non-null  string
#  24  attributes.declawed         14116 non-null  string
#  25  attributes.special_needs    34009 non-null  string
#  26  attributes.shots_current    34009 non-null  string
#  27  environment.children        11391 non-null  string
#  28  environment.dogs            12411 non-null  string
#  29  environment.cats            10485 non-null  string
#  30  contact.address.city        34009 non-null  string
#  31  contact.address.state       34009 non-null  string
#  32  contact.address.postcode    34009 non-null  float64
# dtypes: datetime64[ns, UTC](2), float64(2), string(29)
# memory usage: 8.8 MB

# %% [markdown]
# ### Clean name strings

# %%
df['name'] = df['name'].str.strip()  
df['name'] = df['name'].str.title()

# %%
# Check 
#df['name'].value_counts().head(50)

# %% [markdown]
# ### Reformat date column

# %%
# Change published_date format from ISO to normal datetime format
df['published_date'] = df['published_at'].dt.strftime('%m/%d/%y')

# %%
# Change status_change_ date format from ISO to normal datetime format
df['status_change_date'] = df['status_changed_at'].dt.strftime('%m/%d/%y')

# %% [markdown]
# ### Add column for time between published date and status change dates

# %%
df['adoption_time'] = (df['status_changed_at'] - df['published_at']).dt.days

# %% [markdown]
# ### Add month, day, year separate columns

# %%
# Published at
df['month_published'] = df['published_at'].dt.month
df['day_published'] = df['published_at'].dt.day
df['year_published'] = df['published_at'].dt.year
# Status changed at
df['month_status_change'] = df['status_changed_at'].dt.month
df['day_status_change'] = df['status_changed_at'].dt.day
df['year_status_change'] = df['status_changed_at'].dt.year

# %%
# Check
df[['status_change_date', 'published_date', 'adoption_time', 'month_published', 'day_published']].head()
# Out:
#   status_change_date published_date  adoption_time  month_published  \
# 0           01/22/24       12/31/23           21.0             12.0
# 1           01/18/24       12/31/23           17.0             12.0
# 2           01/06/24       12/31/23            5.0             12.0
# 3           12/31/23       12/31/23            0.0             12.0
# 4           12/31/23       12/31/23            0.0             12.0
#
#    day_published
# 0           31.0
# 1           31.0
# 2           31.0
# 3           31.0
# 4           31.0

# %%
#df.columns

# %% [markdown]
# ### Verify the published vs change dates

# %%
max_pub = df['published_at'].max()
min_pub = df['published_at'].min()

max_schange = df['status_changed_at'].max()
min_schange = df['status_changed_at'].min()

print('earliest publish date: ', min_pub)
print('latest publish date: ', max_pub)
print('earliest status change date: ', min_schange)
print('latest status change date: ', max_schange)
# Out:
# earliest publish date:  2023-01-01 00:15:33+00:00
# latest publish date:  2023-12-31 23:19:08+00:00
# earliest status change date:  2023-01-01 05:15:33+00:00
# latest status change date:  2024-02-08 17:28:30+00:00

# %% [markdown]
# ### Clean tags

# %%
df['tags'] = df['tags'].str.strip('[]')

# %%
df['tags'] = df['tags'].str.replace("'", "")

# %%
#df.groupby('tags')['id'].count().reset_index(name='count').sort_values('count', ascending=False).head(50)

# %%
df['tags'] = df['tags'].str.strip()  
df['tags'] = df['tags'].str.title()

# %%
df.tags
# Out:
# 0
# 1                          Friendly, Affectionate, Playful
# 2                          Friendly, Affectionate, Playful
# 3
# 4
#                                ...
# 34397
# 34398                             Shy, Confident, Friendly
# 34399                            Playful, Social, Friendly
# 34400                      Playful, Friendly, Loves Treats
# 34401    Loyal, Gentle, Smart, Curious, Independent, Fr...
# Name: tags, Length: 34010, dtype: string

# %% [markdown]
# ### Clean Cities

# %%
df['contact.address.city'] = df['contact.address.city'].str.strip().str.title()

# %%
df.groupby('contact.address.city')['id'].count().reset_index(name='count').sort_values('count', ascending=False).head()
# Out:
#     contact.address.city  count
# 60           Greeneville  10371
# 132          Shelbyville   2098
# 105            Nashville   2027
# 34            Crossville   2021
# 130          Sevierville    874

# %%
tn_cities = df['contact.address.city'].nunique()
print('Number of Cities:', tn_cities)
# Out:
# Number of Cities: 156

# %%
df.groupby('contact.address.city')['id'].count().head(50)
# Out:
# contact.address.city
# Afton               1
# Alcoa               5
# Andersonville      63
# Antioch           105
# Arlington           9
# Ashland City        5
# Athens             77
# Atoka              12
# Bartlett          157
# Big Rock           19
# Blountville       783
# Bolivar            65
# Brentwood         203
# Bristol           163
# Brownsville        88
# Buchanan            7
# Camden             39
# Caryville          29
# Centerville        25
# Chapel Hill        11
# Chapmansboro        1
# Chattanooga       860
# Chuckey            23
# Church Hill         4
# Clarksville       134
# Cleveland          67
# Clinton             3
# College Grove      10
# Collierville      348
# Columbia          150
# Cookeville        112
# Cordova            27
# Cosby             160
# Covington          93
# Crossville       2021
# Dandridge         418
# Dayton             30
# Dickson            35
# Donelson            8
# Dover              63
# Dowelltown         29
# Duck River         70
# Dyer                1
# Dyersburg         351
# Eagleville         32
# East Ridge          5
# Elizabethton       49
# Erwin             192
# Evensville          3
# Fall Branch         1
# Name: id, dtype: int64

# %% [markdown]
# ### Clean breed strings

# %%
df['breeds.primary'] = df['breeds.primary'].str.strip().str.title()

# %%
df['breeds.secondary'] = df['breeds.secondary'].str.strip().str.title()

# %%
df.groupby('breeds.secondary')['id'].count().reset_index(name='count').sort_values('count', ascending=True).tail()
# Out:
#         breeds.secondary  count
# 74   Domestic Short Hair    371
# 136          Mixed Breed    476
# 110                Hound    530
# 195              Terrier    658
# 122   Labrador Retriever    661

# %% [markdown]
# ### Clean color strings

# %%
#df.columns

# %%
df['colors.primary'] = df['colors.primary'].str.strip().str.title()
df['colors.secondary'] = df['colors.secondary'].str.strip().str.title()
df['colors.tertiary'] = df['colors.tertiary'].str.strip().str.title()

# %%
df.groupby(['colors.primary', 'colors.secondary', 'colors.tertiary'])['id'].count().reset_index(name='count').sort_values('count', ascending=False)
# Out:
#                   colors.primary             colors.secondary  \
# 49                         Black            Brown / Chocolate
# 55                         Black            Brown / Chocolate
# 47                         Black                      Brindle
# 89                         Black  Yellow / Tan / Blond / Fawn
# 361  Yellow / Tan / Blond / Fawn                        Black
# ..                           ...                          ...
# 159            Brown / Chocolate  Yellow / Tan / Blond / Fawn
# 158            Brown / Chocolate  Yellow / Tan / Blond / Fawn
# 157            Brown / Chocolate                White / Cream
# 156            Brown / Chocolate                White / Cream
# 367  Yellow / Tan / Blond / Fawn                White / Cream
#
#                       colors.tertiary  count
# 49                            Bicolor     28
# 55                      White / Cream     24
# 47                      White / Cream     13
# 89                      White / Cream     12
# 361                     White / Cream     12
# ..                                ...    ...
# 159              Gray / Blue / Silver      1
# 158                             Black      1
# 157       Yellow / Tan / Blond / Fawn      1
# 156  Tricolor (Brown, Black, & White)      1
# 367  Tricolor (Brown, Black, & White)      1
#
# [368 rows x 4 columns]

# %%
primary = df['colors.primary'].nunique()
secondary = df['colors.secondary'].nunique()
tertiary = df['colors.tertiary'].nunique()

print('primary colors: ', primary)
print('secondary colors: ', secondary)
print('tertiary colors: ', tertiary)
# Out:
# primary colors:  57
# secondary colors:  55
# tertiary colors:  47

# %%
df.to_csv('../data/cleaned_pets.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34010 entries, 0 to 34401
# Data columns (total 42 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          34009 non-null  float64
#  1   organization_id             34009 non-null  string
#  2   url                         34009 non-null  string
#  3   type                        34009 non-null  string
#  4   species                     34009 non-null  string
#  5   age                         34009 non-null  string
#  6   gender                      34009 non-null  string
#  7   size                        34009 non-null  string
#  8   coat                        13600 non-null  string
#  9   tags                        34009 non-null  string
#  10  name                        34009 non-null  string
#  11  description                 19496 non-null  string
#  12  status                      34009 non-null  string
#  13  status_changed_at           34009 non-null  datetime64[ns, UTC]
#  14  published_at                34009 non-null  datetime64[ns, UTC]
#  15  breeds.primary              34009 non-null  string
#  16  breeds.secondary            8194 non-null   string
#  17  breeds.mixed                34009 non-null  string
#  18  breeds.unknown              34009 non-null  string
#  19  colors.primary              15015 non-null  string
#  20  colors.secondary            5573 non-null   string
#  21  colors.tertiary             716 non-null    string
#  22  attributes.spayed_neutered  34009 non-null  string
#  23  attributes.house_trained    34009 non-null  string
#  24  attributes.declawed         14116 non-null  string
#  25  attributes.special_needs    34009 non-null  string
#  26  attributes.shots_current    34009 non-null  string
#  27  environment.children        11391 non-null  string
#  28  environment.dogs            12411 non-null  string
#  29  environment.cats            10485 non-null  string
#  30  contact.address.city        34009 non-null  string
#  31  contact.address.state       34009 non-null  string
#  32  contact.address.postcode    34009 non-null  float64
#  33  published_date              34009 non-null  object
#  34  status_change_date          34009 non-null  object
#  35  adoption_time               34009 non-null  float64
#  36  month_published             34009 non-null  float64
#  37  day_published               34009 non-null  float64
#  38  year_published              34009 non-null  float64
#  39  month_status_change         34009 non-null  float64
#  40  day_status_change           34009 non-null  float64
#  41  year_status_change          34009 non-null  float64
# dtypes: datetime64[ns, UTC](2), float64(9), object(2), string(29)
# memory usage: 11.2+ MB
